# %%
from preprocess import Preprocessor
import pandas as pd # type: ignore

import warnings

# Bỏ qua tất cả các cảnh báo
warnings.filterwarnings("ignore")

import logging

logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
relative_path = "../../resources/data/all_data.csv"

df = pd.read_csv(relative_path)

df.head()
# Out:
#                                         Article link  \
# 0  https://www.theblock.co/post/198755/the-block-...
# 1  https://blockchainmagazine.net/the-rise-of-met...
# 2  https://blockchainmagazine.net/how-blockchain-...
# 3  https://blockchainmagazine.net/how-to-protect-...
# 4  https://101blockchains.com/blockchain-technolo...
#
#                    Website source  Article type  \
# 0         https://www.theblock.co  News Article
# 1  https://blockchainmagazine.net     Blog Post
# 2  https://blockchainmagazine.net     Blog Post
# 3  https://blockchainmagazine.net     Blog Post
# 4      https://101blockchains.com     Blog Post
#
#                                        Article title  \
# 0  The Block Researchâ€™s Analysts: 2023 Predictions
# 1  The Rise Of Metaverse Economy- Top 10 Things I...
# 2  How Blockchain And Metaverse Can Revolutionize...
# 3  How To Protect Yourself From Fraud In Metavers...
# 4  Blockchain Technology Explained: A Decentraliz...
#
#                                              Content  Creation date  \
# 0  Consensus predictions Overall macro environmen...            NaN
# 1  The Metaverse is a term that refers to a virtu...            NaN
# 2  Blockchain is a decentralized digital ledger t...            NaN
# 3  The concept of the metaverse has gained signif...            NaN
# 4  Blockchain technology is more or less, slowly ...     2021-07-30
#
#           Author  Category  Tags  Summary  Unnamed: 10  Unnamed: 11
# 0            NaN       NaN   NaN      NaN          NaN          NaN
# 1  Diana Ambolis       NaN   NaN      NaN          NaN          NaN
# 2  Diana Ambolis       NaN   NaN      NaN          NaN          NaN
# 3  Diana Ambolis       NaN   NaN      NaN          NaN          NaN
# 4    Hasib Anwar    Guides   NaN      NaN          NaN          NaN

# %%
df[' content length'] = df[' Content'].astype(str).apply(len)
df = df.sort_values(by=' content length', ascending=False)
df = df.drop(columns=[' content length'])
df = df[:27000]
df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 27000 entries, 0 to 27006
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Article link     27000 non-null  object
#  1    Website source  27000 non-null  object
#  2    Article type    27000 non-null  object
#  3    Article title   26989 non-null  object
#  4    Content         27000 non-null  object
#  5    Creation date   20047 non-null  object
#  6    Author          24838 non-null  object
#  7    Category        25835 non-null  object
#  8    Tags            17527 non-null  object
#  9    Summary         9645 non-null   object
#  10  Unnamed: 10      0 non-null      float64
#  11  Unnamed: 11      0 non-null      float64
# dtypes: float64(2), object(10)
# memory usage: 2.7+ MB

# %%
relative_path = "../../resources/data/NordFX.csv"

fb_df = pd.read_csv(relative_path)

fb_df.head()
# Out:
#                       Article link                   Website source  \
# 0  https://www.facebook.com/NordFX  https://www.facebook.com/NordFX
# 1  https://www.facebook.com/NordFX  https://www.facebook.com/NordFX
# 2  https://www.facebook.com/NordFX  https://www.facebook.com/NordFX
# 3  https://www.facebook.com/NordFX  https://www.facebook.com/NordFX
# 4  https://www.facebook.com/NordFX  https://www.facebook.com/NordFX
#
#     Article type  Article title  \
# 0  Facebook post              -
# 1  Facebook post              -
# 2  Facebook post              -
# 3  Facebook post              -
# 4  Facebook post              -
#
#                                              Content  Creation date  Author  \
# 0  Forex and Cryptocurrency Forecast for 27 – 31 ...              -  NordFX
# 1   7 Tips to Stay Ahead of Market Shifts\nNaviga...              -  NordFX
# 2  CryptoNews\n– On 20-21 May, bitcoin surged sha...              -  NordFX
# 3   How does seasonality impact forex markets?\nS...              -  NordFX
# 4  Forex and Cryptocurrency Forecast for 20 – 24 ...              -  NordFX
#
#    Category  Tags  Summary
# 0         -     -        -
# 1         -     -        -
# 2         -     -        -
# 3         -     -        -
# 4         -     -        -

# %%
df= pd.concat([df, fb_df], ignore_index=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28226 entries, 0 to 28225
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Article link     28226 non-null  object
#  1    Website source  28226 non-null  object
#  2    Article type    28226 non-null  object
#  3    Article title   28215 non-null  object
#  4    Content         28226 non-null  object
#  5    Creation date   21273 non-null  object
#  6    Author          26064 non-null  object
#  7    Category        27061 non-null  object
#  8    Tags            18753 non-null  object
#  9    Summary         10871 non-null  object
#  10  Unnamed: 10      0 non-null      float64
#  11  Unnamed: 11      0 non-null      float64
# dtypes: float64(2), object(10)
# memory usage: 2.6+ MB

# %%
preprocessor = Preprocessor()

# %%
df[' Creation date'] = df[' Creation date'].apply(preprocessor.preprocess_date)
df.head()
# Out:
#                                         Article link  \
# 0  https://www.theblock.co/post/198755/the-block-...
# 1  https://blockchainmagazine.net/the-rise-of-met...
# 2  https://blockchainmagazine.net/how-blockchain-...
# 3  https://blockchainmagazine.net/how-to-protect-...
# 4  https://101blockchains.com/blockchain-technolo...
#
#                    Website source  Article type  \
# 0         https://www.theblock.co  News Article
# 1  https://blockchainmagazine.net     Blog Post
# 2  https://blockchainmagazine.net     Blog Post
# 3  https://blockchainmagazine.net     Blog Post
# 4      https://101blockchains.com     Blog Post
#
#                                        Article title  \
# 0  The Block Researchâ€™s Analysts: 2023 Predictions
# 1  The Rise Of Metaverse Economy- Top 10 Things I...
# 2  How Blockchain And Metaverse Can Revolutionize...
# 3  How To Protect Yourself From Fraud In Metavers...
# 4  Blockchain Technology Explained: A Decentraliz...
#
#                                              Content  Creation date  \
# 0  Consensus predictions Overall macro environmen...            NaT
# 1  The Metaverse is a term that refers to a virtu...            NaT
# 2  Blockchain is a decentralized digital ledger t...            NaT
# 3  The concept of the metaverse has gained signif...            NaT
# 4  Blockchain technology is more or less, slowly ...     2021-07-30
#
#           Author  Category  Tags  Summary  Unnamed: 10  Unnamed: 11
# 0            NaN       NaN   NaN      NaN          NaN          NaN
# 1  Diana Ambolis       NaN   NaN      NaN          NaN          NaN
# 2  Diana Ambolis       NaN   NaN      NaN          NaN          NaN
# 3  Diana Ambolis       NaN   NaN      NaN          NaN          NaN
# 4    Hasib Anwar    Guides   NaN      NaN          NaN          NaN

# %%
df.to_csv("../../resources/data/all_data.csv", index=False)

# %%
df[' Article title'] = df[' Article title'].apply(preprocessor.preprocess_text)
df[' Author'] = df[' Author'].apply(preprocessor.preprocess_text)
df[' Content'] = df[' Content'].apply(preprocessor.preprocess_text)
df[' Category'] = df[' Category'].apply(preprocessor.preprocess_text)
df[' Tags'] = df[' Tags'].apply(preprocessor.preprocess_text)


df.head(10)
# Out:
#                                         Article link  \
# 0  https://www.theblock.co/post/198755/the-block-...
# 1  https://blockchainmagazine.net/the-rise-of-met...
# 2  https://blockchainmagazine.net/how-blockchain-...
# 3  https://blockchainmagazine.net/how-to-protect-...
# 4  https://101blockchains.com/blockchain-technolo...
# 5           https://blockonomi.com/axitrader-review/
# 6    https://101blockchains.com/blockchain-glossary/
# 7         https://blockonomi.com/markets-com-review/
# 8          https://blockonomi.com/expressvpn-review/
# 9             https://blockonomi.com/plus500-review/
#
#                    Website source  Article type  \
# 0         https://www.theblock.co  News Article
# 1  https://blockchainmagazine.net     Blog Post
# 2  https://blockchainmagazine.net     Blog Post
# 3  https://blockchainmagazine.net     Blog Post
# 4      https://101blockchains.com     Blog Post
# 5          https://blockonomi.com  News Article
# 6      https://101blockchains.com     Blog Post
# 7          https://blockonomi.com  News Article
# 8          https://blockonomi.com  News Article
# 9          https://blockonomi.com  News Article
#
#                                        Article title  \
# 0           block researchâs analyst 2023 prediction
# 1        rise metaverse economy top 10 change future
# 2         blockchain metaverse revolutionize tourism
# 3  protect yourself fraud metaverse type fraud me...
# 4  blockchain technology explain decentralize eco...
# 5   beginnerâs guide axitrader broke complete review
# 6  ultimate blockchain glossary beginner 46 block...
# 7  beginnerâs guide marketscom broke complete review
# 8           expressvpn review premium vpn provider â
# 9          beginnerâs guide plus 500 complete review
#
#                                              Content  Creation date  \
# 0  consensus prediction overall macro environment...            NaT
# 1  metaverse term refer virtual universe collecti...            NaT
# 2  blockchain decentralize digital ledger technol...            NaT
# 3  concept metaverse gain significant attention p...            NaT
# 4  blockchain technology slowly take digital worl...     2021-07-30
# 5  axitrader pride found trader platform understa...            NaT
# 6  zat 101 blockchains believe blockchain technol...     2018-07-01
# 7  marketscom technically marketscom global cfd f...            NaT
# 8  expressvpn consistently rate top vpn provider ...            NaT
# 9  plus 500 industry leader provide contract diff...            NaT
#
#             Author  Category  Tags  Summary  Unnamed: 10  Unnamed: 11
# 0              nan       nan   nan      NaN          NaN          NaN
# 1    diana ambolis       nan   nan      NaN          NaN          NaN
# 2    diana ambolis       nan   nan      NaN          NaN          NaN
# 3    diana ambolis       nan   nan      NaN          NaN          NaN
# 4      hasib anwar     guide   nan      NaN          NaN          NaN
# 5      oliver dale    broker   nan      NaN          NaN          NaN
# 6  101 blockchains     guide   nan      NaN          NaN          NaN
# 7      oliver dale    broker   nan      NaN          NaN          NaN
# 8      oliver dale   privacy   nan      NaN          NaN          NaN
# 9      oliver dale    broker   nan      NaN          NaN          NaN

# %%
dropped_columns = ['Article link', ' Website source', ' Article type', ' Summary']
df.drop(columns=dropped_columns, inplace=True)
df.head()
# Out:
#                                        Article title  \
# 0           block researchâs analyst 2023 prediction
# 1        rise metaverse economy top 10 change future
# 2         blockchain metaverse revolutionize tourism
# 3  protect yourself fraud metaverse type fraud me...
# 4  blockchain technology explain decentralize eco...
#
#                                              Content  Creation date  \
# 0  consensus prediction overall macro environment...            NaT
# 1  metaverse term refer virtual universe collecti...            NaT
# 2  blockchain decentralize digital ledger technol...            NaT
# 3  concept metaverse gain significant attention p...            NaT
# 4  blockchain technology slowly take digital worl...     2021-07-30
#
#           Author  Category  Tags  Unnamed: 10  Unnamed: 11
# 0            nan       nan   nan          NaN          NaN
# 1  diana ambolis       nan   nan          NaN          NaN
# 2  diana ambolis       nan   nan          NaN          NaN
# 3  diana ambolis       nan   nan          NaN          NaN
# 4    hasib anwar     guide   nan          NaN          NaN

# %%
df.to_csv("../../resources/data/preprocessed.csv", index=False)
